# %%
import yolov5
import os

# %%
os.getcwd()
os.chdir('yolov5')

# %%
os.getcwd()
# Out:
# '/Users/jackpeele/Documents/Data Science/DS 6050/final_project/dolphin_whale_classification/yolov5'

# %% [markdown]
# ### Run the YOLOv5 model
# - run the detect.py file, stored in the yolov5 repo
# - use best model weights, list path to best.pt file
# - output is saved yol

# %%
# !python detect.py --source ../../train_images/train_images_sub/ --weights ../copy_model_output/exp18/weights/best.pt --conf 0.25 --name yolo_fin_det --save-crop
# Out:
# detect: weights=['../copy_model_output/exp18/weights/best.pt'], source=../../train_images/train_images_sub/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=yolo_fin_det, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# fatal: cannot change to '/Users/jackpeele/Documents/Data': No such file or directory
# YOLOv5 🚀 2022-4-26 torch 1.8.0 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/11824 /Users/jackpeele/Documents/Data Science/DS 6050/final_project/train_images/train_images_sub/0007c33415ce37.jpg: 448x640 1 fin, Done. (0.191s)
# ...
